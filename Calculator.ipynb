# %%
import math
from tkinter import *
from tkinter import ttk
window= Tk()
window.title('CALCULATOR')
window.geometry('186x220')
 
def b1():
    length = len(textbox.get())
    textbox.insert(length, 1)
def b2():
    length = len(textbox.get())
    textbox.insert(length, 2)
def b3():
    length = len(textbox.get())
    textbox.insert(length, 3)
def b4():
    length = len(textbox.get())
    textbox.insert(length, 4)
def b5():
    length = len(textbox.get())
    textbox.insert(length, 5)
def b6():
    length = len(textbox.get())
    textbox.insert(length, 6)
def b7():
    length = len(textbox.get())
    textbox.insert(length, 7)
def b8():
    length = len(textbox.get())
    textbox.insert(length, 8)
def b9():
    length = len(textbox.get())
    textbox.insert(length, 9)
def b10():
    length = len(textbox.get())
    textbox.insert(length, 0)
def b11():
    length = len(textbox.get())
    textbox.insert(length,'-')
def b12():
    length = len(textbox.get())
    textbox.insert(length, '*')
def b13():
    length = len(textbox.get())
    textbox.insert(length, '/')
def b14():
    length = len(textbox.get())
    textbox.insert(length, '+')
def b15():
    length = len(textbox.get())
    result = eval(textbox.get())
    textbox.delete(0,length)
    
    textbox.insert(0,result)
def b16():
    length = len(textbox.get())
    textbox.insert(length, '.')
def b17():
    length = len(textbox.get())
    textbox.delete(0,length)
def b18():
    length = len(textbox.get())
    textbox.insert(length, '**(.5)')
    length = len(textbox.get())
    result = eval(textbox.get())
    textbox.delete(0,length)
    textbox.insert(0,result) 
    
b1=Button(window,text='1',height=3, width=3,pady=5,fg='white',bg="gray70",command=b1)
b2=Button(window,text='2',height=3, width=3,pady=5,fg='white',bg="gray70",command=b2)
b3=Button(window,text='3',height=3, width=3,pady=5,fg='white',bg="gray70",command=b3)
b4=Button(window,text='4',height=3, width=3,pady=5,fg='white',bg="gray70",command=b4)
b5=Button(window,text='5',height=3, width=3,pady=5,fg='white',bg="gray70",command=b5)
b6=Button(window,text='6',height=3, width=3,pady=5,fg='white',bg="gray70",command=b6)
b7=Button(window,text='7',height=3, width=3,pady=5,fg='white',bg="gray70",command=b7)
b8=Button(window,text='8',height=3, width=3,pady=5,fg='white',bg="gray70",command=b8)
b9=Button(window,text='9',height=3, width=3,pady=5,fg='white',bg="gray70",command=b9)
b10=Button(window,text='0',height=3, width=3,pady=5,fg='white',bg="gray70",command=b10)
b11=Button(window,text='-',height=3, width=3,pady=5,fg='white',bg="black",command=b11)
b12=Button(window,text='x',height=3, width=3,pady=5,fg='white',bg="black",command=b12)
b13=Button(window,text='/',height=3, width=3,pady=5,fg='white',bg="black",command=b13)
b14=Button(window,text='+',height=3, width=3,pady=5,fg='white',bg="black",command=b14)
b15=Button(window,text='=',height=3, width=3,pady=5,fg='white',bg='orange',command =b15)
b16=Button(window,text='.',height=3, width=3,pady=5,fg='white',bg="black",command =b16)
b17=Button(window,text='C',height=3, width=3,pady=5,fg='white',bg='orange',command =b17)
b18=Button(window,text='√',height=3, width=3,pady=5,fg='white',bg="black",command =b18)
b1.grid(column=0,row=1,sticky=W)
b2.grid(column=1,row=1,sticky=W)
b3.grid(column=2,row=1,sticky=W)
b4.grid(column=0,row=2,sticky=W)
b5.grid(column=1,row=2,sticky=W)
b6.grid(column=2,row=2,sticky=W)
b7.grid(column=0,row=3,sticky=W)
b8.grid(column=1,row=3,sticky=W)
b9.grid(column=2,row=3,sticky=W)
b10.grid(column=3,row=1,sticky=W)
b11.grid(column=3,row=2,sticky=W)
b12.grid(column=3,row=3,sticky=W)
b13.grid(column=4,row=1,sticky=W)
b14.grid(column=4,row=2,sticky=W)
b15.grid(column=5,row=3,sticky=W)
b16.grid(column=5,row=1,sticky=W)
b17.grid(column=5,row=2,sticky=W)
b18.grid(column=4,row=3,sticky=W)
textbox = Entry(window,font='Arial')
textbox.grid(row=0, column=0, columnspan=6, ipady=2, pady=2)

window.mainloop()
